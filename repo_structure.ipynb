# %% [markdown]
# # Estrutura do Repositório
# **Projecto: Pipeline de Classificação do Cancro do Pulmão (TCIA + ResNet + YOLOv8 + LLMs)**
#
# ---
#
# ## 1. Estrutura Geral do Repositório
#
# ```plaintext
# Repository Structure:
#
# ├── README.md
# ├── configs
# │   ├── yolo   [contains files inside]
# ├── data
# │   ├── NSCLC-Radiomics-Lung1.clinical-version3-Oct-2019.csv
# │   ├── TMN_LUNGPETDX_NSCLC_finaldataset.csv
# │   ├── dataset
# │   │   ├── final_images_dataset.pkl
# │   ├── dataset_tnm   [contains files inside]
# │   ├── metadata.csv
# │   ├── metadata_sampled.csv
# │   ├── raw   [contains files inside]
# │   ├── sampled   [contains files inside]
# │   ├── statistics_clinical.xlsx
# │   ├── yolo   [contains files inside]
# ├── docs
# ├── models
# │   ├── resnet50
# │   │   ├── multimodal_resnet50.py
# │   ├── yolo   [contains files inside]
# │   ├── yolo_resnet
# ├── notebooks
# │   ├── 01_yolov8_cancer_classification
# │   │   ├── 01_LUNGPETCT_data_preprocessing.ipynb
# │   │   ├── 02_LUNGPETCT_image_preprocessing.ipynb
# │   │   ├── 03_NSLC_image_preprocessing.ipynb
# │   │   ├── 04_NSLC_data_preprocessing.ipynb
# │   │   ├── 05_preprocessing_LUNGPET_NSCLC.ipynb
# │   │   ├── 06_resnet50_optimizing.ipynb
# │   │   ├── 07_yolov8_model_training.ipynb
# │   │   ├── 08_yolov8_model_eval.ipynb
# │   ├── 02_resnet50_tnm_staging
# │   │   ├── 01_data_processing_TNM_stage.ipynb
# │   │   ├── 02_image_processing_TNM_stage.ipynb
# │   │   ├── 03_resnet50_TMN.ipynb
# │   ├── 03_llm_treatment_generation
# │   │   ├── 01_LLM_preprocessing-Copy1.ipynb
# │   │   ├── 02_LLM_evaluation-Copy2.ipynb
# │   ├── pipeline_classification_and_treatment.ipynb
# ├── repo_structure.ipynb
# ├── repo_structure.txt
# ├── results
# │   ├── yolo_test
# │   │   ├── test_YOLO_orig(16batch)   [contains files inside]
# │   │   ├── test_YOLOorig_nano(16batch)_E_G   [contains files inside]
# │   │   ├── test_YOLOorig_nano(16batch)_E_G_2   [contains files inside]
# │   │   ├── test_YOLOorig_nano(16batch)_E_G_last   [contains files inside]
# │   │   ├── test_YOLOorig_nano(32batch)_E_G   [contains files inside]
# │   │   ├── test_YOLOorig_small(16batch)   [contains files inside]
# │   │   ├── test_YOLOorig_small(16batch)_E_G_2   [contains files inside]
# │   │   ├── test_YOLOorig_small(16batch)_E_G_best   [contains files inside]
# │   │   ├── test_YOLOorig_small(32batch)_E_G   [contains files inside]
# │   │   ├── test_lung_cancer_detection_ResNet50   [contains files inside]
# ├── src
# │   ├── augmentation
# │   │   ├── __pycache__   [contains files inside]
# │   │   ├── augmentation_utils.py
# │   │   ├── augmentation_yolo.py
# │   ├── modeling
# │   │   ├── llms
# │   │   ├── resnet50
# │   │   │   ├── datasets
# │   │   │   │   ├── lung_cancer_dataset.py
# │   │   │   │   ├── lung_cancer_multimodal.py
# │   │   │   ├── eval_multimodal_resnet50.py
# │   │   │   ├── eval_resnet50.py
# │   │   │   ├── train_multimodal_resnet50.py
# │   │   │   ├── train_resnet50.py
# │   ├── nlp
# │   │   ├── api
# │   │   │   ├── config.py
# │   │   │   ├── gemini_2flash.py
# │   │   │   ├── gpt4omini.py
# │   │   ├── prompt
# │   │   │   ├── prompt.py
# │   │   ├── rag
# │   │   │   ├── chromadb.py
# │   │   │   ├── chunking.py
# │   │   │   ├── embeddings.py
# │   │   │   ├── embeddings_openai.py
# │   │   │   ├── embeddings_utils.py
# │   │   │   ├── rag_pipeline.py
# │   │   │   ├── retrieval.py
# │   │   ├── utils
# │   │   │   ├── text_cleaning.py
# │   ├── optimization
# │   │   ├── loaders
# │   │   │   ├── data_loader.py
# │   │   ├── objectives
# │   │   │   ├── objective_generic.py
# │   │   │   ├── objective_sgd.py
# │   │   │   ├── objective_sgd_steplr.py
# │   │   │   ├── objective_sgd_steplr_intensive_search.py
# │   │   │   ├── objective_tnm.py
# │   │   ├── optuna_results
# │   │   │   ├── TNM   [contains files inside]
# │   │   │   ├── best_hyperparameters_40epochs.json
# │   │   │   ├── best_hyperparameters_SGD.json
# │   │   │   ├── best_hyperparameters_SGD_StepLR.json
# │   │   │   ├── best_hyperparameters_SGD_StepLR_50epochs.json
# │   │   │   ├── best_hyperparameters_SGD_StepLR_50epochs_2.json
# │   │   │   ├── best_hyperparameters_objective_generic.json
# │   │   │   ├── trial_results   [contains files inside]
# │   │   │   ├── trial_results_40epochs   [contains files inside]
# │   │   │   ├── trial_results_SGD   [contains files inside]
# │   │   │   ├── trial_results_SGD_StepLR   [contains files inside]
# │   │   │   ├── trial_results_SGD_StepLR_50epochs   [contains files inside]
# │   │   │   ├── trial_results_SGD_StepLR_50epochs_2   [contains files inside]
# │   │   ├── optuna_results_TNM   [contains files inside]
# │   │   ├── utils
# │   │   │   ├── reproducibility.py
# │   ├── preprocessing
# │   │   ├── __pycache__   [contains files inside]
# │   │   ├── dataset_building.py
# │   │   ├── dicom_io.py
# │   │   ├── image_preprocessing.py
# │   │   ├── nlp
# │   │   │   ├── pdf_preprocessing.py
# │   │   │   ├── web_scraping_utils.py
# │   │   ├── rtstruct
# │   │   │   ├── __pycache__   [contains files inside]
# │   │   │   ├── rtstruct_batch_processing.py
# │   │   │   ├── rtstruct_io.py
# │   │   │   ├── rtstruct_parsing.py
# │   │   │   ├── rtstruct_to_yolo.py
# │   │   │   ├── rtstruct_visualization.py
# │   │   ├── sampling.py
# │   │   ├── uid_mapping.py
# │   │   ├── xml_parsing.py
# │   │   ├── yolo_conversion.py
# │   ├── splitting
# │   │   ├── __pycache__   [contains files inside]
# │   │   ├── dataset_splitting.py
# │   ├── statistics
# │   │   ├── __pycache__   [contains files inside]
# │   │   ├── patient_label_statistics.py
# │   ├── training
# │   │   ├── ResNet50
# │   │   │   ├── final_training
# │   │   │   │   ├── ResNet50_final_model_1.pth
# │   │   │   │   ├── ResNet50_final_model_2.pth
# │   │   │   │   ├── ResNet50_final_model_4.pth
# │   │   │   ├── final_training_TMN
# │   │   │   │   ├── ResNet50_52
# │   │   │   │   │   ├── ResNet50_final_model_TMN_52.pth
# │   │   │   │   ├── ResNet50_9
# │   │   │   │   │   ├── ResNet50_final_model_TMN_9.pth
# │   │   │   │   │   ├── plots_9
# │   │   │   │   ├── ResNet50_final_model_TMN_dropout_15.pth
# │   │   │   │   ├── ResNet50_final_model_TMN_dropout_35.pth
# │   ├── utils
# │   │   ├── __pycache__   [contains files inside]
# │   │   ├── extract_number.py
# │   │   ├── file_utils.py
# │   │   ├── subject_utils.py
# │   ├── visualization
# │   │   ├── __pycache__   [contains files inside]
# │   │   ├── patient_visualization.py
# │   │   ├── plot_bboxes.py
# │   │   ├── yolo_visualization.py
# ├── tree.py

# %% [markdown]
# ---
# ### **1. Dados TCIA fora do Git**
# - Manter imagens DICOM localmente.
# - Reproduzível através de scripts de download.
# - `.gitignore` impede carregar ficheiros volumosos.
#
# ### **2. Módulos separados por função**
# - `preprocessing/` → normalizações, segmentações pulmonares, preparação das imagens.
# - `modeling/` → modelos independentes:
#   - ResNet (classificação),
#   - YOLOv8 (detecção),
#   - LLMs (protocolos TNM, relatórios clínicos).
#
# ### **3. Configurações YAML**
# - Reproduzibilidade experimental.
# - Separação clara entre código e parâmetros.
#
# ### **4. Notebooks organizados por fluxo científico**
# - Exploração → Pré-processamento → Experimentos → Relatórios LLM.
#
# ### **5. Diretório `results/`**
# - Curvas, matrizes de confusão, métricas TNM.
#
# ---
#
# ## .gitignore
# - data/raw/
# - data/processed/*.npy
# - models/checkpoints/
# - *.ckpt
# - *.pt
# - *.pth
# - *.h5
# - __pycache__/
# - .ipynb_checkpoints/
# - .env

# %% [markdown]
# # FUNCTION → SCRIPT ASSIGNMENT
# (Updated including **all your latest changes**:
# ✔ added NSCLC renaming utilities
# ✔ `get_patient_images_v2()` replaces old version
# ✔ `split_data_nsclc()` replaces split_data
# ✔ full RTSTRUCT module retained)
#
# ---
#
# # 🧩 UTILS MODULE
#
# ## **src/utils/extract_number.py**
# ### Contains:
# - `extract_number()`
#
# ---
#
#
# ### **src/utils/subject_utils.py**
# ### Contains:
# - `count_unique_subject_ids()`
# - `patient_count_by_group()`
# - `count_labels_by_class_and_source()`
# - `count_labels_by_class()`
# - `count_images_labels_patients_by_class()`
# - `get_patient_images()`
# - `get_patient_images_v2()`
# - `sample_patients_by_image_count()`
# - `sample_patients()`
# - `count_files_and_patients()`
# - `extract_patient_id_2datasets()`
# - `count_images_labels_patients_by_class_total()`
# - `count_images_labels_patients_by_class_2datasets()`
#
#
# ---
#
# ## **src/utils/file_utils.py**
# ### Contains:
# - `load_dataset()`
# - `loadFileInformation()`
# - `rename_files_in_folder()`
# - `count_files_by_prefix()`
# - `update_label_files()`
# - generic filesystem helpers (os, shutil, glob)
#
# ---
#
# ## **src/utils/metrics_utils.py**
# ### Contains:
# - *(empty – reserved for ML metrics)*
#
# ---
#
# # 🧩 PREPROCESSING MODULE
#
# ## **src/preprocessing/sampling.py**
# ### Contains:
# - `relaxed_stratified_sample()`
# - `add_more_patients()`
# - `get_target_sample()`
# - `adjust_sample_size()`
# - `calculate_stage_distribution()`
# - `compare_distributions()`
# - `check_balance()`
#
# ---
#
# ## **src/preprocessing/dicom_io.py**
# ### Contains:
# - `read_dicom_image()` *(TCIA version)*
#
# ---
#
# ## **src/preprocessing/uid_mapping.py**
# ### Contains:
# - `getUID_path()`
#
# ---
#
# ## **src/preprocessing/xml_parsing.py**
# ### Contains:
# - `extract_bounding_boxes()`
#
# ---
#
# ## **src/preprocessing/dataset_building.py**
# ### Contains:
# - `create_dataset()`
# - `get_images_by_patient_id()`
#
# ---
#
# ## **src/preprocessing/yolo_conversion.py**
# ### Contains:
# - `preprocess_images()` *(DICOM → YOLO)*
#
# ---
#
# ## **src/preprocessing/image_preprocessing.py**
# ### Contains:
# - resizing helpers
# - normalization logic
# - *(empty for now, but preserved)*
#
# ---
#
# # 🆕 RTSTRUCT PROCESSING MODULE
# Folder: `src/preprocessing/rtstruct/`
#
# This includes all functions related to **RTSTRUCT parsing, conversion and visualization**.
#
# ---
#
# ## **src/preprocessing/rtstruct/rtstruct_io.py**
# ### Contains:
# - `load_rtstruct()`
# - `load_ct_images()`
# - `read_dicom_image()` *(RTSTRUCT-specific)*
#
# ---
#
# ## **src/preprocessing/rtstruct/rtstruct_parsing.py**
# ### Contains:
# - `extract_tumor_bboxes()`
#
# ---
#
# ## **src/preprocessing/rtstruct/rtstruct_to_yolo.py**
# ### Contains:
# - `save_yolo_format()`
# - `save_images_as_jpeg()`
# - `load_yolo_labels()`
# - `draw_bboxes()`
#
# ---
#
# ## **src/preprocessing/rtstruct/rtstruct_visualization.py**
# ### Contains:
# - `visualize_bboxes()`
# - `display_all_images_for_patient()`
#
# ---
#
# ## **src/preprocessing/rtstruct/rtstruct_batch_processing.py**
# ### Contains:
# - `process_all_patients()`
#
# ---
#
# # 🧩 VISUALIZATION MODULE
#
# ## **src/visualization/plot_images.py**
# ### Contains:
# - general image plotting utilities
#
# ---
#
# ## **src/visualization/plot_bboxes.py**
# ### Contains:
# - `visualize_image_with_bboxes()`
# - `visualize_image_with_bboxes_legend()`
#
# ---
#
# ## **src/visualization/patient_visualization.py**
# ### Contains:
# - `visualize_image_by_uid()`
#
# ---
#
# ## **src/visualization/yolo_visualization.py**
# ### Contains:
# - `visualize_yolo_images()`
#
# ---
#
# ## **src/visualization/plot_distributions.py**
# ### Contains:
# - (future) class & stage distribution plots
#
# ---
#
# # 🧩 AUGMENTATION MODULE
#
# ## **src/augmentation/augmentation_yolo.py**
# ### Contains:
# - `augment_yolo_images_train()`
# - `augment_yolo_images_val()`
#
# ---
#
# ## **src/augmentation/augmentation_utils.py**
# ### Contains:
# - augmentation pipelines
# - bbox transform utilities
#
# ---
#
# # 🧩 DATA SPLITTING MODULE
#
# ## **src/splitting/dataset_splitting.py**
# ### Contains:
# - `copy_sampled_files()`
# - `copy_files()`
# - `split_data_nsclc()` ← **RENAMED from split_data**
# - `main()` *(orchestrates NSCLC small-batch dataset creation)*
# - `split_data_2datasets()`
#
# ---
#
# # 🧩 STATISTICS MODULE
#
# ## **src/statistics/stage_distributions.py**
# ### Contains:
# - (future) stage distribution plot utilities
#
# ---
#
# ## **src/statistics/cohort_balance.py**
# ### Contains:
# - cohort balancing tools
# - (optional mirror of sampling functions)
#
# ---
#
# # 📌 SUMMARY TABLE (UPDATED + COMPLETE)
#
# | Function                                  | Assigned Script                                           |
# |-------------------------------------------|------------------------------------------------------------|
# | extract_number                             | utils/extract_number.py                                    |
# | count_unique_subject_ids                   | utils/subject_utils.py                                     |
# | patient_count_by_group                     | utils/subject_utils.py                                     |
# | count_labels_by_class                      | utils/subject_utils.py                                     |
# | count_labels_by_class_and_source           | utils/subject_utils.py                                     |
# | count_images_labels_patients_by_class      | utils/subject_utils.py                                     |
# | count_files_and_patients                   | utils/subject_utils.py                                     |
# | get_patient_images_v2                      | utils/subject_utils.py                                     |
# | sample_patients_by_image_count             | utils/subject_utils.py                                     |
# | sample_patients                            | utils/subject_utils.py                                     |
# | load_dataset                               | utils/file_utils.py                                        |
# | loadFileInformation                        | utils/file_utils.py                                        |
# | rename_files_in_folder                     | utils/file_utils.py                                        |
# | count_files_by_prefix                      | utils/file_utils.py                                        |
# | update_label_files                         | utils/file_utils.py                                        |
# | relaxed_stratified_sample                  | preprocessing/sampling.py                                  |
# | add_more_patients                          | preprocessing/sampling.py                                  |
# | get_target_sample                          | preprocessing/sampling.py                                  |
# | adjust_sample_size                         | preprocessing/sampling.py                                  |
# | calculate_stage_distribution               | preprocessing/sampling.py                                  |
# | compare_distributions                      | preprocessing/sampling.py                                  |
# | check_balance                              | preprocessing/sampling.py                                  |
# | read_dicom_image (TCIA)                    | preprocessing/dicom_io.py                                  |
# | getUID_path                                | preprocessing/uid_mapping.py                               |
# | extract_bounding_boxes                     | preprocessing/xml_parsing.py                               |
# | create_dataset                             | preprocessing/dataset_building.py                          |
# | get_images_by_patient_id                   | preprocessing/dataset_building.py                          |
# | preprocess_images                          | preprocessing/yolo_conversion.py                           |
# | load_rtstruct                              | preprocessing/rtstruct/rtstruct_io.py                      |
# | load_ct_images                             | preprocessing/rtstruct/rtstruct_io.py                      |
# | read_dicom_image (RTSTRUCT)                | preprocessing/rtstruct/rtstruct_io.py                      |
# | extract_tumor_bboxes                       | preprocessing/rtstruct/rtstruct_parsing.py                 |
# | save_yolo_format                           | preprocessing/rtstruct/rtstruct_to_yolo.py                 |
# | save_images_as_jpeg                        | preprocessing/rtstruct/rtstruct_to_yolo.py                 |
# | load_yolo_labels                            | preprocessing/rtstruct/rtstruct_to_yolo.py                 |
# | draw_bboxes                                | preprocessing/rtstruct/rtstruct_to_yolo.py                 |
# | visualize_bboxes                           | preprocessing/rtstruct/rtstruct_visualization.py           |
# | display_all_images_for_patient             | preprocessing/rtstruct/rtstruct_visualization.py           |
# | process_all_patients                       | preprocessing/rtstruct/rtstruct_batch_processing.py        |
# | visualize_image_with_bboxes                | visualization/plot_bboxes.py                               |
# | visualize_image_with_bboxes_legend         | visualization/plot_bboxes.py                               |
# | visualize_image_by_uid                     | visualization/patient_visualization.py                     |
# | visualize_yolo_images                      | visualization/yolo_visualization.py                        |
# | augment_yolo_images_train                  | augmentation/augmentation_yolo.py                          |
# | augment_yolo_images_val                    | augmentation/augmentation_yolo.py                          |
# | split_data_nsclc                           | splitting/dataset_splitting.py                             |
# | stage_distribution_plots (future)          | statistics/stage_distributions.py                          |
# | cohort_balance (future mirror)             | statistics/cohort_balance.py                               |
#
# ---
